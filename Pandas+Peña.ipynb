# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
df1 = pd.read_csv('./datos/Summer-Olympic-medals-1976-to-2008.csv') #Cargo el archivo csv como un dataframe con Pandas

# %%
df1.head() #Veo un pantallazo del dataframe
# Out:
#        City    Year     Sport Discipline           Event  \
# 0  Montreal  1976.0  Aquatics     Diving  3m springboard
# 1  Montreal  1976.0  Aquatics     Diving  3m springboard
# 2  Montreal  1976.0  Aquatics     Diving  3m springboard
# 3  Montreal  1976.0  Aquatics     Diving  3m springboard
# 4  Montreal  1976.0  Aquatics     Diving    10m platform
#
#                     Athlete Gender Country_Code        Country Event_gender  \
# 0           K�HLER, Christa  Women          GDR   East Germany            W
# 1       KOSENKOV, Aleksandr    Men          URS   Soviet Union            M
# 2      BOGGS, Philip George    Men          USA  United States            M
# 3  CAGNOTTO, Giorgio Franco    Men          ITA          Italy            M
# 4    WILSON, Deborah Keplar  Women          USA  United States            W
#
#     Medal
# 0  Silver
# 1  Bronze
# 2    Gold
# 3  Silver
# 4  Bronze

# %%
df1.shape #Realizo pasos previos para verificar y tratar el dataframe
# Out:
# (15433, 11)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15433 entries, 0 to 15432
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          15316 non-null  object
#  1   Year          15316 non-null  float64
#  2   Sport         15316 non-null  object
#  3   Discipline    15316 non-null  object
#  4   Event         15316 non-null  object
#  5   Athlete       15316 non-null  object
#  6   Gender        15316 non-null  object
#  7   Country_Code  15316 non-null  object
#  8   Country       15316 non-null  object
#  9   Event_gender  15316 non-null  object
#  10  Medal         15316 non-null  object
# dtypes: float64(1), object(10)
# memory usage: 1.3+ MB

# %%
df1.isna().sum() #Verifico cuántas filas no tienen registros
# Out:
# City            117
# Year            117
# Sport           117
# Discipline      117
# Event           117
# Athlete         117
# Gender          117
# Country_Code    117
# Country         117
# Event_gender    117
# Medal           117
# dtype: int64

# %%
df1[df1.isna()]
# Out:
#       City  Year Sport Discipline Event Athlete Gender Country_Code Country  \
# 0      NaN   NaN   NaN        NaN   NaN     NaN    NaN          NaN     NaN
# 1      NaN   NaN   NaN        NaN   NaN     NaN    NaN          NaN     NaN
# 2      NaN   NaN   NaN        NaN   NaN     NaN    NaN          NaN     NaN
# 3      NaN   NaN   NaN        NaN   NaN     NaN    NaN          NaN     NaN
# 4      NaN   NaN   NaN        NaN   NaN     NaN    NaN          NaN     NaN
# ...    ...   ...   ...        ...   ...     ...    ...          ...     ...
# 15428  NaN   NaN   NaN        NaN   NaN     NaN    NaN          NaN     NaN
# 15429  NaN   NaN   NaN        NaN   NaN     NaN    NaN          NaN     NaN
# 15430  NaN   NaN   NaN        NaN   NaN     NaN    NaN          NaN     NaN
# 15431  NaN   NaN   NaN        NaN   NaN     NaN    NaN          NaN     NaN
# 15432  NaN   NaN   NaN        NaN   NaN     NaN    NaN          NaN     NaN
#
#       Event_gender Medal
# 0              NaN   NaN
# ...

# %%
df2 = df1.dropna() #Creo el dataframe sin los NaN

# %%
df2 #Veo un pantallazo de la tabla
# Out:
#            City    Year      Sport       Discipline           Event  \
# 0      Montreal  1976.0   Aquatics           Diving  3m springboard
# 1      Montreal  1976.0   Aquatics           Diving  3m springboard
# 2      Montreal  1976.0   Aquatics           Diving  3m springboard
# 3      Montreal  1976.0   Aquatics           Diving  3m springboard
# 4      Montreal  1976.0   Aquatics           Diving    10m platform
# ...         ...     ...        ...              ...             ...
# 15428   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15429   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15430   Beijing  2008.0  Wrestling  Wrestling Gre-R       55 - 60kg
# 15431   Beijing  2008.0  Wrestling  Wrestling Gre-R       60 - 66kg
# 15432   Beijing  2008.0  Wrestling  Wrestling Gre-R      96 - 120kg
#
#                         Athlete Gender Country_Code        Country  \
# 0               K�HLER, Christa  Women          GDR   East Germany
# ...

# %%
serie_years = df2.Year #Creo la serie de tiempo por años
serie_years_pandas = pd.to_datetime(serie_years,format='%Y')

# %%
df2.head()
df3 = df2.drop(['Year'], axis=1)

# %% [markdown]
# # Punto 1 Construir un objeto de series de tiempo con en índice el año

# %%
df3.set_index(serie_years_pandas)#Punto 1 Construir un objeto de series de tiempo con el índice igual al año de los juegos olímpicos
# Out:
#                 City      Sport       Discipline           Event  \
# Year
# 1976-01-01  Montreal   Aquatics           Diving  3m springboard
# 1976-01-01  Montreal   Aquatics           Diving  3m springboard
# 1976-01-01  Montreal   Aquatics           Diving  3m springboard
# 1976-01-01  Montreal   Aquatics           Diving  3m springboard
# 1976-01-01  Montreal   Aquatics           Diving    10m platform
# ...              ...        ...              ...             ...
# 2008-01-01   Beijing  Wrestling  Wrestling Gre-R       66 - 74kg
# 2008-01-01   Beijing  Wrestling  Wrestling Gre-R       66 - 74kg
# 2008-01-01   Beijing  Wrestling  Wrestling Gre-R       55 - 60kg
# 2008-01-01   Beijing  Wrestling  Wrestling Gre-R       60 - 66kg
# 2008-01-01   Beijing  Wrestling  Wrestling Gre-R      96 - 120kg
#
#                              Athlete Gender Country_Code        Country  \
# Year
# 1976-01-01           K�HLER, Christa  Women          GDR   East Germany
# ...

# %% [markdown]
# # Punto 2 Separar nombres y apellidos en dos columnas distintas usando la coma

# %%
nombre_apellido = df2.Athlete.str.split(',',expand=True)
nombre_apellido
# Out:
#                0                1     2
# 0         K�HLER          Christa  None
# 1       KOSENKOV        Aleksandr  None
# 2          BOGGS    Philip George  None
# 3       CAGNOTTO   Giorgio Franco  None
# 4         WILSON   Deborah Keplar  None
# ...          ...              ...   ...
# 15428     GUENOT       Christophe  None
# 15429  KVIRKELIA         Manuchar  None
# 15430    RAHIMOV          Vitaliy  None
# 15431     GUENOT           Steeve  None
# 15432      LOPEZ           Mijain  None
#
# [15316 rows x 3 columns]

# %%
(nombre_apellido.isna().sum()/nombre_apellido.shape[0])*100 #Verificamos el porcentaje en la columna 2 que están vacíos
# Out:
# 0     0.000000
# 1     0.607208
# 2    99.908592
# dtype: float64

# %%
colsNombreApellido = nombre_apellido.drop(2,axis=1)
colsNombreApellido.rename(columns={0:'Nombre',1:'Apellido'})
# Out:
#           Nombre         Apellido
# 0         K�HLER          Christa
# 1       KOSENKOV        Aleksandr
# 2          BOGGS    Philip George
# 3       CAGNOTTO   Giorgio Franco
# 4         WILSON   Deborah Keplar
# ...          ...              ...
# 15428     GUENOT       Christophe
# 15429  KVIRKELIA         Manuchar
# 15430    RAHIMOV          Vitaliy
# 15431     GUENOT           Steeve
# 15432      LOPEZ           Mijain
#
# [15316 rows x 2 columns]

# %% [markdown]
# # Punto 3 Obtener medida resumen del conjunto de datos ¿Cuál país ganó mas medallas?

# %%
df2.sample(3)
# Out:
#            City    Year          Sport       Discipline  \
# 6072  Barcelona  1992.0      Athletics        Athletics
# 6643  Barcelona  1992.0        Fencing          Fencing
# 6453  Barcelona  1992.0  Canoe / Kayak  Canoe / Kayak F
#
#                         Event            Athlete Gender Country_Code  \
# 6072             hammer throw    NIKOULINE, Igor    Men          EUN
# 6643                �p�e team  CHOUVALOV, Andrei    Men          EUN
# 6453  C-2 500m (canoe double)      PAPKE, Ulrich    Men          GER
#
#            Country Event_gender   Medal
# 6072  Unified team            M  Bronze
# 6643  Unified team            M  Bronze
# 6453       Germany            M  Silver

# %%
dfResumen = df2.set_index('Year')
dfResumen.describe()
# Out:
#            City     Sport Discipline   Event          Athlete Gender  \
# count     15316     15316      15316   15316            15316  15316
# unique        9        28         41     293            11337      2
# top     Beijing  Aquatics  Athletics  hockey  PHELPS, Michael    Men
# freq       2042      2210       1523     817               16   9388
#
#        Country_Code        Country Event_gender   Medal
# count         15316          15316        15316   15316
# unique          128            127            3       3
# top             USA  United States            M  Bronze
# freq           1992           1992         8817    5258

# %%
#En el paso anterior nos muestra que Estados Unidos es el país que tiene mas medallas ganadas
dfResumen.T.describe()
# Out:
# Year      1976.0    1976.0    1976.0    1976.0    1976.0    1976.0    1976.0  \
# count         10        10        10        10        10        10        10
# unique        10        10        10        10        10        10        10
# top     Aquatics  Aquatics  Aquatics  Aquatics  Aquatics  Aquatics  Aquatics
# freq           1         1         1         1         1         1         1
#
# Year      1976.0    1976.0    1976.0  ...           2008.0   2008.0  \
# count         10        10        10  ...               10       10
# unique        10        10        10  ...               10       10
# top     Aquatics  Aquatics  Aquatics  ...  Wrestling Gre-R  Armenia
# freq           1         1         1  ...                1        1
#
# Year             2008.0           2008.0   2008.0   2008.0           2008.0  \
# count                10               10       10       10               10
# unique               10               10       10       10               10
# ...

# %%
df2.groupby('Country')['Medal'].count().sort_values(ascending=False) #Acá verificamos que efectivamente Estados Unidos es el país con mas medallas
# Out:
# Country
# United States    1992
# Soviet Union     1021
# Australia         798
# Germany           691
# China             679
#                  ...
# Panama              1
# Senegal             1
# Sri Lanka           1
# Sudan               1
# Macedonia           1
# Name: Medal, Length: 127, dtype: int64

# %% [markdown]
# # Punto 4 Construir una tabla que muestre cuántas medallas obtuvieron los hombres en total en cada año que se realizó el evento.

# %%
df2.head() #Vemos los nombres de las columnas y obtenemos que su nombre es Event_gender
# Out:
#        City    Year     Sport Discipline           Event  \
# 0  Montreal  1976.0  Aquatics     Diving  3m springboard
# 1  Montreal  1976.0  Aquatics     Diving  3m springboard
# 2  Montreal  1976.0  Aquatics     Diving  3m springboard
# 3  Montreal  1976.0  Aquatics     Diving  3m springboard
# 4  Montreal  1976.0  Aquatics     Diving    10m platform
#
#                     Athlete Gender Country_Code        Country Event_gender  \
# 0           K�HLER, Christa  Women          GDR   East Germany            W
# 1       KOSENKOV, Aleksandr    Men          URS   Soviet Union            M
# 2      BOGGS, Philip George    Men          USA  United States            M
# 3  CAGNOTTO, Giorgio Franco    Men          ITA          Italy            M
# 4    WILSON, Deborah Keplar  Women          USA  United States            W
#
#     Medal
# 0  Silver
# 1  Bronze
# 2    Gold
# 3  Silver
# 4  Bronze

# %%
dfHombres = df2[df2.Event_gender == 'M'] #Creamos un dataframe con solo los hombres
dfHombres
# Out:
#            City    Year      Sport       Discipline           Event  \
# 1      Montreal  1976.0   Aquatics           Diving  3m springboard
# 2      Montreal  1976.0   Aquatics           Diving  3m springboard
# 3      Montreal  1976.0   Aquatics           Diving  3m springboard
# 5      Montreal  1976.0   Aquatics           Diving    10m platform
# 8      Montreal  1976.0   Aquatics           Diving    10m platform
# ...         ...     ...        ...              ...             ...
# 15428   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15429   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15430   Beijing  2008.0  Wrestling  Wrestling Gre-R       55 - 60kg
# 15431   Beijing  2008.0  Wrestling  Wrestling Gre-R       60 - 66kg
# 15432   Beijing  2008.0  Wrestling  Wrestling Gre-R      96 - 120kg
#
#                         Athlete Gender Country_Code        Country  \
# 1           KOSENKOV, Aleksandr    Men          URS   Soviet Union
# ...

# %%
dfTotalHombres = dfHombres.groupby(['Year', 'Event_gender'])['Event_gender'].count() #Monstramos el dataframe con solo el Año y el Género
dfTotalHombres.to_frame()
# Out:
#                      Event_gender
# Year   Event_gender
# 1976.0 M                      843
# 1980.0 M                      854
# 1984.0 M                      911
# 1988.0 M                      950
# 1992.0 M                     1041
# 1996.0 M                     1029
# 2000.0 M                     1065
# 2004.0 M                     1052
# 2008.0 M                     1072
